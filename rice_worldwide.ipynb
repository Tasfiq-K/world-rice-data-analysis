# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the data

# %%
data = pd.read_csv("/content/drive/MyDrive/Dataset/FAOSTAT_data_en_5-14-2023.csv")
data.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)         Area  \
# 0         QCL  Crops and livestock products                4  Afghanistan
# 1         QCL  Crops and livestock products                4  Afghanistan
# 2         QCL  Crops and livestock products                4  Afghanistan
# 3         QCL  Crops and livestock products                4  Afghanistan
# 4         QCL  Crops and livestock products                4  Afghanistan
#
#    Element Code     Element  Item Code (CPC)  Item  Year Code  Year    Unit  \
# 0          5510  Production              113  Rice       2017  2017  tonnes
# 1          5510  Production              113  Rice       2018  2018  tonnes
# 2          5510  Production              113  Rice       2019  2019  tonnes
# 3          5510  Production              113  Rice       2020  2020  tonnes
# 4          5510  Production              113  Rice       2021  2021  tonnes
#
#        Value Flag Flag Description
# 0  338420.00    A  Official figure
# 1  352177.00    A  Official figure
# 2  382500.00    A  Official figure
# 3  439549.00    A  Official figure
# 4  458571.64    I    Imputed value

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       702 non-null    object
#  1   Domain            702 non-null    object
#  2   Area Code (M49)   702 non-null    int64
#  3   Area              702 non-null    object
#  4   Element Code      702 non-null    int64
#  5   Element           702 non-null    object
#  6   Item Code (CPC)   702 non-null    int64
#  7   Item              702 non-null    object
#  8   Year Code         702 non-null    int64
#  9   Year              702 non-null    int64
#  10  Unit              702 non-null    object
#  11  Value             702 non-null    float64
#  12  Flag              702 non-null    object
#  13  Flag Description  702 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 76.9+ KB

# %%
## Let's check out the data using the describe method

data.describe()
# Out:
#        Area Code (M49)  Element Code  Item Code (CPC)    Year Code  \
# count        702.00000         702.0            702.0   702.000000
# mean         427.47151        5510.0            113.0  2019.051282
# std          253.45120           0.0              0.0     1.396017
# min            4.00000        5510.0            113.0  2017.000000
# 25%          196.00000        5510.0            113.0  2018.000000
# 50%          413.50000        5510.0            113.0  2019.000000
# 75%          643.00000        5510.0            113.0  2020.000000
# max          894.00000        5510.0            113.0  2021.000000
#
#               Year         Value
# count   702.000000  7.020000e+02
# mean   2019.051282  6.965645e+06
# std       1.396017  3.014558e+07
# min    2017.000000  0.000000e+00
# 25%    2018.000000  2.690590e+03
# 50%    2019.000000  1.602925e+05
# 75%    2020.000000  1.243050e+06
# max    2021.000000  2.144299e+08

# %%
for col in data.columns:
    print(f"Column: {col}\nNumber of Unique elements: {data[col].nunique()}")
    print(f"Unique elements: {data[col].unique()}\n" + "--" * 80)
# Out:
# Column: Domain Code
# Number of Unique elements: 1
# Unique elements: ['QCL']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Domain
# Number of Unique elements: 1
# Unique elements: ['Crops and livestock products']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Area Code (M49)
# Number of Unique elements: 144
# Unique elements: [  4   8  12  24  32  51  36  31  50  56  84 204  64  68  76  96 100 854
#  108 116 120 140 148 152 159 344 156 158 170 174 178 188 384 191 192 196
#  203 408 180 208 214 218 818 222 233 748 231 242 246 250 266 270 276 288
#  300 320 324 624 328 332 340 348 356 360 364 368 372 380 388 392 398 404
#  417 418 428 430 440 442 450 454 458 466 470 478 480 484 583 504 508 104
#  524 528 554 558 562 566 807 586 591 598 600 604 608 616 620 630 410 498
#  642 643 646 670 682 686 694 703 705  90 706 710 728 724 144 729 740 752
#  760 762 764 626 768 780 792 795 800 804 834 840 858 860 862 704 894 716]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Area
# Number of Unique elements: 144
# Unique elements: ['Afghanistan' 'Albania' 'Algeria' 'Angola' 'Argentina' 'Armenia'
#  'Australia' 'Azerbaijan' 'Bangladesh' 'Belgium' 'Belize' 'Benin' 'Bhutan'
#  'Bolivia (Plurinational State of)' 'Brazil' 'Brunei Darussalam'
#  'Bulgaria' 'Burkina Faso' 'Burundi' 'Cambodia' 'Cameroon'
#  'Central African Republic' 'Chad' 'Chile' 'China' 'China, Hong Kong SAR'
#  'China, mainland' 'China, Taiwan Province of' 'Colombia' 'Comoros'
#  'Congo' 'Costa Rica' "Côte d'Ivoire" 'Croatia' 'Cuba' 'Cyprus' 'Czechia'
#  "Democratic People's Republic of Korea"
#  'Democratic Republic of the Congo' 'Denmark' 'Dominican Republic'
#  'Ecuador' 'Egypt' 'El Salvador' 'Estonia' 'Eswatini' 'Ethiopia' 'Fiji'
#  'Finland' 'France' 'Gabon' 'Gambia' 'Germany' 'Ghana' 'Greece'
#  'Guatemala' 'Guinea' 'Guinea-Bissau' 'Guyana' 'Haiti' 'Honduras'
#  'Hungary' 'India' 'Indonesia' 'Iran (Islamic Republic of)' 'Iraq'
#  'Ireland' 'Italy' 'Jamaica' 'Japan' 'Kazakhstan' 'Kenya' 'Kyrgyzstan'
#  "Lao People's Democratic Republic" 'Latvia' 'Liberia' 'Lithuania'
#  'Luxembourg' 'Madagascar' 'Malawi' 'Malaysia' 'Mali' 'Malta' 'Mauritania'
#  'Mauritius' 'Mexico' 'Micronesia (Federated States of)' 'Morocco'
#  'Mozambique' 'Myanmar' 'Nepal' 'Netherlands (Kingdom of the)'
#  'New Zealand' 'Nicaragua' 'Niger' 'Nigeria' 'North Macedonia' 'Pakistan'
#  'Panama' 'Papua New Guinea' 'Paraguay' 'Peru' 'Philippines' 'Poland'
#  'Portugal' 'Puerto Rico' 'Republic of Korea' 'Republic of Moldova'
#  'Romania' 'Russian Federation' 'Rwanda'
#  'Saint Vincent and the Grenadines' 'Saudi Arabia' 'Senegal'
#  'Sierra Leone' 'Slovakia' 'Slovenia' 'Solomon Islands' 'Somalia'
#  'South Africa' 'South Sudan' 'Spain' 'Sri Lanka' 'Sudan' 'Suriname'
#  'Sweden' 'Syrian Arab Republic' 'Tajikistan' 'Thailand' 'Timor-Leste'
#  'Togo' 'Trinidad and Tobago' 'Türkiye' 'Turkmenistan' 'Uganda' 'Ukraine'
#  'United Republic of Tanzania' 'United States of America' 'Uruguay'
#  'Uzbekistan' 'Venezuela (Bolivarian Republic of)' 'Viet Nam' 'Zambia'
#  'Zimbabwe']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Element Code
# Number of Unique elements: 1
# Unique elements: [5510]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Element
# Number of Unique elements: 1
# Unique elements: ['Production']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Item Code (CPC)
# Number of Unique elements: 1
# Unique elements: [113]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Item
# Number of Unique elements: 1
# Unique elements: ['Rice']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Year Code
# Number of Unique elements: 5
# Unique elements: [2017 2018 2019 2020 2021]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Year
# Number of Unique elements: 5
# Unique elements: [2017 2018 2019 2020 2021]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Unit
# Number of Unique elements: 1
# Unique elements: ['tonnes']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Value
# Number of Unique elements: 581
# Unique elements: [3.38420000e+05 3.52177000e+05 3.82500000e+05 4.39549000e+05
#  4.58571640e+05 0.00000000e+00 3.16140000e+02 3.15340000e+02
#  3.12780000e+02 3.14750000e+02 3.14290000e+02 9.42600000e+03
#  9.69900000e+03 1.01020000e+04 1.05670000e+04 1.05140000e+04
#  1.32834000e+06 1.36796800e+06 1.18986600e+06 1.22291000e+06
#  1.45318700e+06 8.07304460e+05 6.35113000e+05 6.68353400e+04
#  5.02263300e+04 4.22977540e+05 1.59157000e+04 1.19746000e+04
#  1.10700000e+04 9.39730000e+03 1.00623000e+04 5.41480000e+07
#  5.44160000e+07 5.45863440e+07 5.49058910e+07 5.69445540e+07
#  1.87510000e+04 1.33750000e+04 1.39000000e+04 1.39420000e+04
#  1.49900000e+04 2.78717550e+05 4.59313020e+05 4.06082780e+05
#  4.11578140e+05 5.19666840e+05 8.63850000e+04 6.38898200e+04
#  4.99480500e+04 5.40884000e+04 4.05079000e+04 4.78578450e+05
#  5.41157000e+05 6.00044000e+05 4.87427000e+05 5.50181520e+05
#  1.24647660e+07 1.18084120e+07 1.03686390e+07 1.10910110e+07
#  1.16606030e+07 1.52700000e+03 1.56900000e+03 1.49995000e+03
#  2.51131000e+03 2.67500000e+03 5.85230000e+04 6.07200000e+04
#  7.09200000e+04 6.58100000e+04 5.81200000e+04 3.25566000e+05
#  3.50392000e+05 3.76527250e+05 4.51421000e+05 4.51000000e+05
#  8.82979000e+04 8.92962000e+04 2.41210700e+05 1.50000000e+05
#  1.20000000e+05 1.05180000e+07 1.08920000e+07 1.08857000e+07
#  1.12480000e+07 1.14100000e+07 2.60000000e+05 3.34200000e+05
#  3.34442990e+05 3.39974360e+05 3.62294450e+05 1.20000000e+04
#  1.25520000e+04 1.30550000e+04 1.28089600e+04 2.63555000e+05
#  2.59539850e+05 2.90563000e+05 2.78052850e+05 2.42646700e+05
#  1.27866000e+05 1.92808000e+05 1.74897200e+05 1.69697000e+05
#  1.46085100e+05 2.14429949e+08 2.14078796e+08 2.11405211e+08
#  2.13610729e+08 2.14403870e+08 5.00000000e-02 2.12675900e+08
#  2.12129000e+08 2.09614000e+08 2.11860000e+08 2.12843000e+08
#  1.75404900e+06 1.94979600e+06 1.79121100e+06 1.75072900e+06
#  1.56087000e+06 3.29298300e+06 2.94485985e+06 3.01231094e+06

# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Flag
# Number of Unique elements: 5
# Unique elements: ['A' 'I' 'M' 'E' 'T']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Column: Flag Description
# Number of Unique elements: 5
# Unique elements: ['Official figure' 'Imputed value'
#  'Missing value (data cannot exist, not applicable)' 'Estimated value'
#  'Unofficial figure']
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Let's first drop a few column and change a few column names

# %%
data.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
data.drop(['Domain Code', 'Domain', 'Element Code', 'Item Code (CPC)', 'Item', 'Year Code', 'Unit'], axis=1, inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Area Code (M49)', 'Area', 'Element', 'Year', 'Value', 'Flag',
#        'Flag Description'],
#       dtype='object')

# %%
data.head(1)
# Out:
#    Area Code (M49)         Area     Element  Year     Value Flag  \
# 0                4  Afghanistan  Production  2017  338420.0    A
#
#   Flag Description
# 0  Official figure

# %%
data.rename(columns={'Value': 'Value (tonnes)'}, inplace=True)

# %%
data.head()
# Out:
#    Area Code (M49)         Area     Element  Year  Value (tonnes) Flag  \
# 0                4  Afghanistan  Production  2017       338420.00    A
# 1                4  Afghanistan  Production  2018       352177.00    A
# 2                4  Afghanistan  Production  2019       382500.00    A
# 3                4  Afghanistan  Production  2020       439549.00    A
# 4                4  Afghanistan  Production  2021       458571.64    I
#
#   Flag Description
# 0  Official figure
# 1  Official figure
# 2  Official figure
# 3  Official figure
# 4    Imputed value

# %%
data[data['Value (tonnes)'] == data['Value (tonnes)'].max()]
# Out:
#      Area Code (M49)   Area     Element  Year  Value (tonnes) Flag  \
# 119              159  China  Production  2017    2.144299e+08    E
#
#     Flag Description
# 119  Estimated value

# %% [markdown]
# What are the top 5 countries that produces rice in terms of quantity

# %%
data.loc[data['Year'] == 2021].sort_values(by='Value (tonnes)', ascending=False).head(10)
# Out:
#      Area Code (M49)             Area     Element  Year  Value (tonnes) Flag  \
# 123              159            China  Production  2021    2.144039e+08    E
# 133              156  China, mainland  Production  2021    2.128430e+08    A
# 306              356            India  Production  2021    1.954250e+08    A
# 44                50       Bangladesh  Production  2021    5.694455e+07    I
# 311              360        Indonesia  Production  2021    5.441529e+07    A
# 691              704         Viet Nam  Production  2021    4.385273e+07    A
# 626              764         Thailand  Production  2021    3.358200e+07    A
# 436              104          Myanmar  Production  2021    2.491000e+07    T
# 500              608      Philippines  Production  2021    1.996017e+07    A
# 475              586         Pakistan  Production  2021    1.398401e+07    A
#
#       Flag Description
# 123    Estimated value
# 133    Official figure
# 306    Official figure
# 44       Imputed value
# 311    Official figure
# 691    Official figure
# 626    Official figure
# 436  Unofficial figure
# 500    Official figure
# 475    Official figure
